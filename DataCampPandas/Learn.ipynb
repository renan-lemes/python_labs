# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv('CarBuyers.csv')

# %%
df.head()
# Out:
#   Manufacturer   Model      Price  Transmission       Power    Engine CC  \
# 0         Ford   Focus  30.619322      5.966102   94.033898  1497.169492
# 1         Ford  Fiesta  18.532143      5.714286   68.571429  1166.142857
# 2   Volkswagen    Golf  31.242154      6.164835   89.461538  1537.406593
# 3      Renault    Clio  22.100000      5.615385   75.576923  1219.653846
# 4          BMW    320i  47.848370      6.444444  126.111111  1995.777778
#
#      Fuel    Male  Female Unknown    Total
# 0  petrol  814172  422731  56,487  1293390
# 1  petrol  554879  631666  54,057  1240602
# 2  petrol  483216  310604  47,563   841383
# 3  petrol  241287  312556  28,004   581847
# 4  petrol  408016  115843  29,125   552984

# %%
print(df.isna().sum())
# Out:
# Manufacturer    0
# Model           0
# Price           0
# Transmission    0
# Power           0
# Engine CC       0
# Fuel            0
# Male            0
# Female          0
# Unknown         0
# Total           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6092 entries, 0 to 6091
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Manufacturer  6092 non-null   object
#  1   Model         6092 non-null   object
#  2   Price         6092 non-null   float64
#  3   Transmission  6092 non-null   float64
#  4   Power         6092 non-null   float64
#  5   Engine CC     6092 non-null   float64
#  6   Fuel          6092 non-null   object
#  7   Male          6092 non-null   object
#  8   Female        6092 non-null   object
#  9   Unknown       6092 non-null   object
#  10  Total         6092 non-null   object
# dtypes: float64(4), object(7)
# memory usage: 523.7+ KB

# %%
df.shape
# Out:
# (6092, 11)

# %%
df.describe()
# Out:
#              Price  Transmission        Power    Engine CC
# count  6092.000000   6092.000000  6092.000000  6092.000000
# mean     41.230074      5.131491   111.478881  1982.083952
# std      51.357916      1.343858    67.621849   817.410323
# min       3.332200      0.000000    15.600000     0.000000
# 25%      18.513000      4.600000    70.250000  1497.127119
# 50%      29.043000      5.000000    94.062500  1832.888889
# 75%      43.863631      5.966102   121.857143  2247.333333
# max     646.605000      8.277311   450.000000  6208.000000

# %%
df.values
# Out:
# array([['Ford', 'Focus', 30.61932203, ..., '422731', '56,487', '1293390'],
#        ['Ford', 'Fiesta', 18.53214286, ..., '631666', '54,057',
#         '1240602'],
#        ['Volkswagen', 'Golf', 31.24215385, ..., '310604', '47,563',
#         '841383'],
#        ...,
#        ['Alfa-Romeo', 'Spider', 55.2, ..., '247', '81', '1,118'],
#        ['Honda', 'Shuttle', 30.081, ..., '416', '49', '1,104'],
#        ['Mitsubishi', 'Space', 23.16515789, ..., '251', '40', '1,012']],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Price', 'Transmission', 'Power', 'Engine CC',
#        'Fuel', 'Male', 'Female', 'Unknown', 'Total'],
#       dtype='object')

# %%
df.sort_values('Price')
#organiza o data frame do menor para o maior os preços no caso #
# Out:
#      Manufacturer    Model     Price  Transmission  Power  Engine CC    Fuel  \
# 4947        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# 5377        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# 4724        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# 5168        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# 4490        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# ...           ...      ...       ...           ...    ...        ...     ...
# 5479      Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
# 1166      Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
# 3312      Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
# 4485      Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
# 389       Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
#
#        Male Female Unknown   Total
# ...

# %%
df.sort_values('Price', ascending=False)
# Out:
#      Manufacturer    Model     Price  Transmission  Power  Engine CC    Fuel  \
# 1166      Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
# 2286      Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
# 389       Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
# 2638      Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
# 5479      Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
# ...           ...      ...       ...           ...    ...        ...     ...
# 5786        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# 4947        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# 5377        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# 5583        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# 5168        Skoda      120    3.3322           4.6   15.6      469.6  petrol
#
#         Male Female Unknown   Total
# ...

# %%
df.sort_values(['Price', 'Male'])
# Out:
#      Manufacturer    Model     Price  Transmission  Power  Engine CC    Fuel  \
# 4490        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# 4724        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# 5583        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# 5786        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# 5972        Skoda      120    3.3322           4.6   15.6      469.6  petrol
# ...           ...      ...       ...           ...    ...        ...     ...
# 4209      Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
# 3312      Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
# 3920      Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
# 3627      Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
# 389       Porsche  Carrera  646.6050           6.0  450.0     5733.0  petrol
#
#         Male Female Unknown   Total
# ...

# %%
df[['Price', 'Male']]
# Out:
#            Price    Male
# 0      30.619322  814172
# 1      18.532143  554879
# 2      31.242154  483216
# 3      22.100000  241287
# 4      47.848370  408016
# ...          ...     ...
# 6087  108.747195   1,012
# 6088   43.548516     670
# 6089   55.200000     790
# 6090   30.081000     639
# 6091   23.165158     721
#
# [6092 rows x 2 columns]

# %%
df['Price'] > 33
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 6087     True
# 6088     True
# 6089     True
# 6090    False
# 6091    False
# Name: Price, Length: 6092, dtype: bool

# %%
df[df['Price']> 33]
# Out:
#      Manufacturer     Model       Price  Transmission       Power  \
# 4             BMW      320i   47.848370      6.444444  126.111111
# 7            Ford    Mondeo   39.973750      1.750000  130.250000
# 13       Mercedes       CLA   46.527400      7.040000  131.600000
# 14           Audi        A4   57.926935      6.161290  149.709677
# 15     Volkswagen    Passat   46.064513      6.487179  125.435897
# ...           ...       ...         ...           ...         ...
# 6085      Porsche   Carrera  646.605000      6.000000  450.000000
# 6086       Nissan    Maxima   34.103571      4.571429  121.857143
# 6087   Land-Rover  Defender  108.747195      7.853659  207.609756
# 6088       Toyota      RAV4   43.548516      1.354839  137.774193
# 6089   Alfa-Romeo    Spider   55.200000      6.000000  163.500000
#
#         Engine CC    Fuel    Male  Female Unknown   Total
# 4     1995.777778  petrol  408016  115843  29,125  552984
# ...

# %%
df[df['Manufacturer'] == 'BMW']
# Out:
#      Manufacturer  Model       Price  Transmission       Power    Engine CC  \
# 4             BMW   320i   47.848370      6.444444  126.111111  1995.777778
# 22            BMW   118i   37.426500      6.200000  104.200000  1796.600000
# 26            BMW   535i   93.714250      8.000000  225.000000  2979.000000
# 72            BMW     X5  113.269333      8.000000  246.333333  2994.666667
# 105           BMW     X3   76.592200      8.000000  184.000000  2396.400000
# ...           ...    ...         ...           ...         ...          ...
# 5918          BMW   320i   47.848370      6.444444  126.111111  1995.777778
# 5935          BMW   535i   93.714250      8.000000  225.000000  2979.000000
# 5981          BMW   740i  115.533000      8.000000  250.000000  2998.000000
# 6045          BMW   640i  114.875833      8.000000  235.000000  2979.000000
# 6076          BMW  M550i  134.789000      8.000000  390.000000  4395.000000
#
#         Fuel    Male  Female Unknown   Total
# ...

# %%
BMW = df['Fuel'].isin(['diesel'])
BMW
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6087     True
# 6088    False
# 6089    False
# 6090    False
# 6091    False
# Name: Fuel, Length: 6092, dtype: bool

# %%
df['Tax'] = df.Price * 0.07

# %%
df
# Out:
#      Manufacturer     Model       Price  Transmission       Power  \
# 0            Ford     Focus   30.619322      5.966102   94.033898
# 1            Ford    Fiesta   18.532143      5.714286   68.571429
# 2      Volkswagen      Golf   31.242154      6.164835   89.461538
# 3         Renault      Clio   22.100000      5.615385   75.576923
# 4             BMW      320i   47.848370      6.444444  126.111111
# ...           ...       ...         ...           ...         ...
# 6087   Land-Rover  Defender  108.747195      7.853659  207.609756
# 6088       Toyota      RAV4   43.548516      1.354839  137.774193
# 6089   Alfa-Romeo    Spider   55.200000      6.000000  163.500000
# 6090        Honda   Shuttle   30.081000      4.000000  110.000000
# 6091   Mitsubishi     Space   23.165158      3.947368   82.157895
#
#         Engine CC    Fuel    Male  Female Unknown    Total       Tax
# 0     1497.169492  petrol  814172  422731  56,487  1293390  2.143353
# ...

# %%
def pct30(column):
    return(column.quantile(0.3))

# %%
df['Price'].agg(pct30)
# Out:
# 20.21333333

# %%
df[['Price', 'Power']].agg(pct30)
# Out:
# Price    20.213333
# Power    74.000000
# dtype: float64

# %%
def pct40(column):
    return(column.quantile(0.4))

# %%
df['Price'].agg([pct30, pct40])
# Out:
# pct30    20.213333
# pct40    23.275800
# Name: Price, dtype: float64

# %%
df['Price'].cumsum()
# Out:
# 0           30.619322
# 1           49.151465
# 2           80.393619
# 3          102.493619
# 4          150.341989
#             ...
# 6087    251021.613128
# 6088    251065.161644
# 6089    251120.361644
# 6090    251150.442644
# 6091    251173.607802
# Name: Price, Length: 6092, dtype: float64

# %%
df['Fuel']
# Out:
# 0       petrol
# 1       petrol
# 2       petrol
# 3       petrol
# 4       petrol
#          ...
# 6087    diesel
# 6088    petrol
# 6089    petrol
# 6090    petrol
# 6091    petrol
# Name: Fuel, Length: 6092, dtype: object

# %%
df[df['Manufacturer'] == 'Land-Rover'].value_counts()
# Out:
# Manufacturer  Model      Price       Transmission  Power       Engine CC    Fuel    Male    Female  Unknown  Total   Tax
# Land-Rover    Defender   108.747195  7.853659      207.609756  2304.975610  diesel  1,012   150     80       1,242   7.612304    1
#                                                                                     1,052   163     89       1,304   7.612304    1
#               Range      107.670513  8.277311      196.336134  2521.092437  diesel  21,917  3,666   602      26,185  7.536936    1
#                                                                                     2,951   270     79       3,300   7.536936    1
#                                                                                     2,540   227     78       2,845   7.536936    1
#                                                                                                                                 ..
# ...

# %%
df[df['Model'] == 'Range'].value_counts()
# Out:
# Manufacturer  Model  Price       Transmission  Power       Engine CC    Fuel    Male    Female  Unknown  Total   Tax
# Land-Rover    Range  107.670513  8.277311      196.336134  2521.092437  diesel  1,532   121     52       1,705   7.536936    1
#                                                                                 1,847   149     65       2,061   7.536936    1
#                                                                                 29,137  5,821   1,366    36,324  7.536936    1
#                                                                                 3,686   341     106      4,133   7.536936    1
#                                                                                 32,159  6,454   1,548    40,161  7.536936    1
#                                                                                 36,627  7,307   1,771    45,705  7.536936    1
# ...

# %%
print(df[df['Manufacturer'] == 'Ford']['Price'].mean())
print(df[df['Manufacturer'] == 'Renault']['Price'].mean())
print(df[df['Manufacturer'] == 'Toyota']['Price'].mean())
print(df[df['Manufacturer'] == 'Honda']['Price'].mean())
# Out:
# 29.604427665549295
# 25.33503906771901
# 31.389270727152596
# 31.766256997447698

# %%
df.groupby('Manufacturer')['Price'].mean()
# Out:
# Manufacturer
# Abarth           21.105625
# Alfa-Romeo       32.991758
# Aston-Martin    244.301839
# Audi             63.241339
# BMW              93.895893
# Bentley         285.247000
# Chevrolet        21.135182
# Chrysler         38.311787
# Citroen          23.348978
# Dacia            17.398333
# Daewoo           16.218534
# Daihatsu         18.542800
# Daimler          87.471833
# Datsun           10.026473
# Dodge            36.172667
# Ferrari         230.242625
# Fiat             19.088152
# Ford             29.604428
# Honda            31.766257
# Hyundai          24.380720
# Jaguar          109.468380
# Kia              24.080534
# Lada             11.167936
# Lancia           29.975534
# Land-Rover       97.214847
# Lexus            75.105448
# Lotus            72.968935
# MG               31.484267
# Maserati        245.168000
# Mazda            25.532133
# Mercedes         69.637917
# Mini             29.188565
# Mitsubishi       25.399497
# ...

# %%
df.groupby('Manufacturer')['Price'].agg([min, max, sum])
# Out:
#                      min         max           sum
# Manufacturer
# Abarth         21.105625   21.105625     84.422500
# Alfa-Romeo     13.818000   55.200000   4882.780172
# Aston-Martin  158.823000  360.755000   7573.357000
# Audi           23.052500  226.383333  18529.712453
# BMW            37.426500  135.105500  19154.762165
# Bentley       285.247000  285.247000   2852.470000
# Chevrolet       9.492273   55.620000   1162.435007
# Chrysler       19.717833   70.319250   2720.136884
# Citroen        10.832750   45.591250   4833.238441
# Dacia          14.040000   20.756667     34.796667
# Daewoo         12.476667   23.245000   1037.986167
# Daihatsu       12.924000   26.197750   1149.653625
# Daimler        71.602000  106.820000   2099.324000
# Datsun          8.400222   11.819286    240.635349
# Dodge          26.591250   47.881000    651.108000
# Ferrari       200.198250  260.287000   2302.426250
# Fiat            3.781000   36.701250   5497.387866
# ...

# %%
print(df.groupby(['Manufacturer', 'Model'])['Price'].mean())
# Out:
# Manufacturer  Model
# Abarth        500C     21.105625
# Alfa-Romeo    145      17.427143
#               146      18.198429
#               147      25.343387
#               155      23.909333
#                          ...
# Volvo         V50      36.524191
#               V60      50.484130
#               V70      50.961091
#               XC70     58.469074
#               XC90     85.829462
# Name: Price, Length: 502, dtype: float64

# %%
print(df.groupby(['Manufacturer', 'Model'])[['Price', 'Power']].mean())
# Out:
#                         Price       Power
# Manufacturer Model
# Abarth       500C   21.105625   60.625000
# Alfa-Romeo   145    17.427143   87.714286
#              146    18.198429   87.714286
#              147    25.343387   95.096774
#              155    23.909333  100.666667
# ...                       ...         ...
# Volvo        V50    36.524191  113.352941
#              V60    50.484130  150.608696
#              V70    50.961091  135.290909
#              XC70   58.469074  148.518518
#              XC90   85.829462  213.153846
#
# [502 rows x 2 columns]

# %%
df.pivot_table(values='Price', index='Manufacturer')
# Out:
#                    Price
# Manufacturer
# Abarth         21.105625
# Alfa-Romeo     32.991758
# Aston-Martin  244.301839
# Audi           63.241339
# BMW            93.895893
# Bentley       285.247000
# Chevrolet      21.135182
# Chrysler       38.311787
# Citroen        23.348978
# Dacia          17.398333
# Daewoo         16.218534
# Daihatsu       18.542800
# Daimler        87.471833
# Datsun         10.026473
# Dodge          36.172667
# Ferrari       230.242625
# Fiat           19.088152
# Ford           29.604428
# Honda          31.766257
# Hyundai        24.380720
# Jaguar        109.468380
# Kia            24.080534
# Lada           11.167936
# Lancia         29.975534
# Land-Rover     97.214847
# Lexus          75.105448
# Lotus          72.968935
# MG             31.484267
# Maserati      245.168000
# Mazda          25.532133
# Mercedes       69.637917
# Mini           29.188565
# Mitsubishi     25.399497
# Morris          6.859333
# Nissan         34.043002
# ...

# %%
df.pivot_table(values='Price', index='Manufacturer', aggfunc=[np.median, np.mean])
# Out:
#                   median        mean
#                    Price       Price
# Manufacturer
# Abarth         21.105625   21.105625
# Alfa-Romeo     32.898125   32.991758
# Aston-Martin  273.755000  244.301839
# Audi           57.926935   63.241339
# BMW           111.993000   93.895893
# Bentley       285.247000  285.247000
# Chevrolet      18.762857   21.135182
# Chrysler       37.471875   38.311787
# Citroen        22.903649   23.348978
# Dacia          17.398333   17.398333
# Daewoo         13.245167   16.218534
# Daihatsu       15.698500   18.542800
# Daimler        92.798000   87.471833
# Datsun          9.580000   10.026473
# Dodge          37.773000   36.172667
# Ferrari       230.242625  230.242625
# Fiat           20.124188   19.088152
# Ford           26.000000   29.604428
# Honda          28.735000   31.766257
# Hyundai        19.055000   24.380720
# Jaguar        137.569546  109.468380
# Kia            22.958714   24.080534
# Lada           10.915800   11.167936
# ...

# %%
df.set_index('Manufacturer')
# Out:
#                  Model       Price  Transmission       Power    Engine CC  \
# Manufacturer
# Ford             Focus   30.619322      5.966102   94.033898  1497.169492
# Ford            Fiesta   18.532143      5.714286   68.571429  1166.142857
# Volkswagen        Golf   31.242154      6.164835   89.461538  1537.406593
# Renault           Clio   22.100000      5.615385   75.576923  1219.653846
# BMW               320i   47.848370      6.444444  126.111111  1995.777778
# ...                ...         ...           ...         ...          ...
# Land-Rover    Defender  108.747195      7.853659  207.609756  2304.975610
# Toyota            RAV4   43.548516      1.354839  137.774193  2261.193548
# Alfa-Romeo      Spider   55.200000      6.000000  163.500000  2696.500000
# Honda          Shuttle   30.081000      4.000000  110.000000  2254.000000
# Mitsubishi       Space   23.165158      3.947368   82.157895  1817.315789
#
#                 Fuel    Male  Female Unknown    Total       Tax
# ...

# %%
df[df['Manufacturer'].isin(['Ford', 'BMW'])]
# Out:
#      Manufacturer     Model       Price  Transmission       Power  \
# 0            Ford     Focus   30.619322      5.966102   94.033898
# 1            Ford    Fiesta   18.532143      5.714286   68.571429
# 4             BMW      320i   47.848370      6.444444  126.111111
# 7            Ford    Mondeo   39.973750      1.750000  130.250000
# 10           Ford       Ka+   15.460000      5.000000   60.800000
# ...           ...       ...         ...           ...         ...
# 6042         Ford   Scorpio   30.862909      4.454545  105.545455
# 6045          BMW      640i  114.875833      8.000000  235.000000
# 6046         Ford  Maverick   29.151000      5.000000   89.000000
# 6066         Ford     Probe   24.840000      5.000000  102.000000
# 6076          BMW     M550i  134.789000      8.000000  390.000000
#
#         Engine CC    Fuel    Male  Female Unknown    Total       Tax
# 0     1497.169492  petrol  814172  422731  56,487  1293390  2.143353
# ...

# %%
df.loc[0:1, 'Power':]
# Out:
#        Power    Engine CC    Fuel    Male  Female Unknown    Total       Tax
# 0  94.033898  1497.169492  petrol  814172  422731  56,487  1293390  2.143353
# 1  68.571429  1166.142857  petrol  554879  631666  54,057  1240602  1.297250

# %%
df_ind = df.set_index(['Manufacturer', 'Tax'])

# %%
df_ind.loc[['Ford', 'Renault']]
# Out:
#                          Model      Price  Transmission       Power  \
# Manufacturer Tax
# Ford         2.143353    Focus  30.619322      5.966102   94.033898
#              1.297250   Fiesta  18.532143      5.714286   68.571429
#              2.798163   Mondeo  39.973750      1.750000  130.250000
#              1.082200      Ka+  15.460000      5.000000   60.800000
#              1.356524   Fusion  19.378909      4.863636   61.272727
# ...                        ...        ...           ...         ...
# Renault      0.925526    Fuego  13.221800      4.600000   70.200000
#              0.461113        4   6.587333      4.000000   22.333333
#              0.642653       14   9.180750      4.000000   46.750000
#              2.225375  Safrane  31.791071      4.571429  104.142857
#              0.696325       20   9.947500      4.750000   73.500000
#
#                          Engine CC    Fuel    Male  Female Unknown    Total
# Manufacturer Tax
# ...

# %%
df_ind.sort_index()
# Out:
#                       Model      Price  Transmission       Power  Engine CC  \
# Manufacturer Tax
# Abarth       1.477394  500C  21.105625           5.0   60.625000     1039.5
#              1.477394  500C  21.105625           5.0   60.625000     1039.5
#              1.477394  500C  21.105625           5.0   60.625000     1039.5
#              1.477394  500C  21.105625           5.0   60.625000     1039.5
# Alfa-Romeo   0.967260    33  13.818000           5.0   66.000000     1351.0
# ...                     ...        ...           ...         ...        ...
# Volvo        6.008062  XC90  85.829462           8.0  213.153846     1969.0
#              6.008062  XC90  85.829462           8.0  213.153846     1969.0
#              6.008062  XC90  85.829462           8.0  213.153846     1969.0
#              6.008062  XC90  85.829462           8.0  213.153846     1969.0
#              6.008062  XC90  85.829462           8.0  213.153846     1969.0
#
# ...

# %%
df_ind.sort_index(level=['Manufacturer', 'Tax'], ascending=[False, True])
# Out:
#                         Model      Price  Transmission       Power  \
# Manufacturer Tax
# Volvo        1.419527     440  20.278963      4.111111   72.851852
#              1.419527     440  20.278963      4.111111   72.851852
#              1.419527     440  20.278963      4.111111   72.851852
#              1.419527     440  20.278963      4.111111   72.851852
#              1.419527     440  20.278963      4.111111   72.851852
# ...                       ...        ...           ...         ...
# Alfa-Romeo   3.864000  Spider  55.200000      6.000000  163.500000
# Abarth       1.477394    500C  21.105625      5.000000   60.625000
#              1.477394    500C  21.105625      5.000000   60.625000
#              1.477394    500C  21.105625      5.000000   60.625000
#              1.477394    500C  21.105625      5.000000   60.625000
#
#                          Engine CC    Fuel   Male Female Unknown   Total
# Manufacturer Tax
# ...

# %%
df.iloc[2:5, 1:3]
# Out:
#   Model      Price
# 2  Golf  31.242154
# 3  Clio  22.100000
# 4  320i  47.848370

# %%
df.Price.hist(bins=12)
df.Power.hist(bins=12, alpha=0.8)
plt.show()

# %%
mean_df_price = df.groupby('Manufacturer')['Price'].mean()
print(mean_df_price.head())
# Out:
# Manufacturer
# Abarth           21.105625
# Alfa-Romeo       32.991758
# Aston-Martin    244.301839
# Audi             63.241339
# BMW              93.895893
# Name: Price, dtype: float64

# %%
mean_df_price.plot(kind='bar', figsize=(18,12))
plt.show()

# %%
df.plot(x='Price', y='Power', kind='scatter', figsize=(18,12))
plt.show()

# %%
df[df['Fuel'] == 'petrol']['Price'].hist(figsize=(12,5))
df[df['Fuel'] == 'diesel']['Price'].hist(figsize=(12,5))
plt.legend(['petrol','diesel'])
plt.show()

# %%
a = ['a', 'b', 'c']
x = a

# %%
x
# Out:
# ['a', 'b', 'c']

# %%
x[1] = 'z'

# %%
a
# Out:
# ['a', 'z', 'c']

# %%
y = list(x) ## or x[:]

# %%
y
# Out:
# ['a', 'z', 'c']

# %%
y[0] = 'b'

# %%
a
# Out:
# ['a', 'z', 'c']

# %%
d = sorted(x, reverse=True)

# %%
d
# Out:
# ['z', 'c', 'a']

# %%
x
# Out:
# ['a', 'z', 'c']

# %%
x.index('c')
# Out:
# 2

# %%
x.append('m')

# %%
x
# Out:
# ['a', 'z', 'c', 'm']

# %%
x.reverse()

# %%
x
# Out:
# ['m', 'c', 'z', 'a']

# %%
num = [1, 6, 7, 8,48]

# %%
num.reverse()

# %%
num
# Out:
# [48, 8, 7, 6, 1]
