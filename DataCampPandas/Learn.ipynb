# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv('amazon_co-ecommerce_sample.csv')

# %%
df.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                       NaN                 2                           1.0
# ...

# %%
df.columns
# Out:
# Index(['uniq_id', 'product_name', 'manufacturer', 'price',
#        'number_available_in_stock', 'number_of_reviews',
#        'number_of_answered_questions', 'average_review_rating',
#        'amazon_category_and_sub_category',
#        'customers_who_bought_this_item_also_bought', 'description',
#        'product_information', 'product_description',
#        'items_customers_buy_after_viewing_this_item',
#        'customer_questions_and_answers', 'customer_reviews', 'sellers'],
#       dtype='object')

# %%
df[df['uniq_id'].isin(['d27964f50577db8e46f2069b050c62c6'])]
# Out:
#                              uniq_id  \
# 15  d27964f50577db8e46f2069b050c62c6
#
#                                          product_name manufacturer price  \
# 15  Glacier Express of N gauge 10-1219 Alps [UNESC...         Kato   NaN
#
#    number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 15                    12 new                 1                           1.0
#
#    average_review_rating                   amazon_category_and_sub_category  \
# 15    5.0 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
#
#            customers_who_bought_this_item_also_bought  \
# 15  http://www.amazon.co.uk/Glacier-Express-Basic-...
#
#                                           description  \
# 15  From 8-year-old: AgeTarget Gender: BoysFrom 8-...
#
#                                   product_information  \
# 15  Technical Details Item Weight671 g Product Dim...
#
#                                   product_description  \
# ...

# %%
df.columns
# Out:
# Index(['uniq_id', 'product_name', 'manufacturer', 'price',
#        'number_available_in_stock', 'number_of_reviews',
#        'number_of_answered_questions', 'average_review_rating',
#        'amazon_category_and_sub_category',
#        'customers_who_bought_this_item_also_bought', 'description',
#        'product_information', 'product_description',
#        'items_customers_buy_after_viewing_this_item',
#        'customer_questions_and_answers', 'customer_reviews', 'sellers'],
#       dtype='object')

# %%
list_itr = [ 'uniq_id', 'product_name', 'manufacturer',
                'price', 'number_available_in_stock', 'number_of_reviews', 'average_review_rating', 'product_description', 'customer_reviews']

# %%
df.groupby('uniq_id')[list_itr]

# %%
df.reset_index().head()
# Out:
#    index                           uniq_id  \
# 0      0  eac7efa5dbd3d667f26eb3d3ab504464
# 1      1  b17540ef7e86e461d37f3ae58b7b72ac
# 2      2  348f344247b0c1a935b1223072ef9d8a
# 3      3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4      4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                       NaN                 2                           1.0
# ...

# %%
df = df.set_index('uniq_id')

# %%
df.head()
# Out:
#                                                                        product_name  \
# uniq_id
# eac7efa5dbd3d667f26eb3d3ab504464                              Hornby 2014 Catalogue
# b17540ef7e86e461d37f3ae58b7b72ac  FunkyBuys® Large Christmas Holiday Express Fes...
# 348f344247b0c1a935b1223072ef9d8a  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# e12b92dbb8eaee78b22965d2a9bbbd9f     HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# e33a9adeed5f36840ccc227db4682a36  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
#
#                                  manufacturer   price  \
# uniq_id
# eac7efa5dbd3d667f26eb3d3ab504464       Hornby   £3.42
# b17540ef7e86e461d37f3ae58b7b72ac    FunkyBuys  £16.99
# 348f344247b0c1a935b1223072ef9d8a          ccf   £9.99
# e12b92dbb8eaee78b22965d2a9bbbd9f       Hornby  £39.99
# e33a9adeed5f36840ccc227db4682a36       Hornby  £32.19
#
#                                  number_available_in_stock number_of_reviews  \
# uniq_id
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, eac7efa5dbd3d667f26eb3d3ab504464 to 94d18e86e504bee1e392df7e5738b18a
# Data columns (total 16 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   product_name                                 10000 non-null  object
#  1   manufacturer                                 9993 non-null   object
#  2   price                                        8565 non-null   object
#  3   number_available_in_stock                    7500 non-null   object
#  4   number_of_reviews                            9982 non-null   object
#  5   number_of_answered_questions                 9235 non-null   float64
#  6   average_review_rating                        9982 non-null   object
#  7   amazon_category_and_sub_category             9310 non-null   object
#  8   customers_who_bought_this_item_also_bought   8938 non-null   object
# ...

# %%
df.drop(['sellers', 'customer_questions_and_answers', 'items_customers_buy_after_viewing_this_item',
        'amazon_category_and_sub_category', 'customers_who_bought_this_item_also_bought'], axis=1)
# Out:
#                                                                        product_name  \
# uniq_id
# eac7efa5dbd3d667f26eb3d3ab504464                              Hornby 2014 Catalogue
# b17540ef7e86e461d37f3ae58b7b72ac  FunkyBuys® Large Christmas Holiday Express Fes...
# 348f344247b0c1a935b1223072ef9d8a  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# e12b92dbb8eaee78b22965d2a9bbbd9f     HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# e33a9adeed5f36840ccc227db4682a36  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                                             ...
# 44d6967f083825a5de36ad4865a65bcd  Batman 1966 TV Series Action Figures - The Rid...
# 08f0747b6fc6687215ffb994c3a6fb32  Star Wars Costume, Kids Stormtrooper Costume S...
# bf6cc073f8f24e6e338190fa16f6ee9d        Defiance Lawkeeper Metal Badge Prop Replica
# cd783d0b8b44e631b9788b203eaaefae  Justice League of America Series 3 Green Lante...
# ...

# %%
price = df['price'].values

# %%
price
# Out:
# array(['£3.42', '£16.99', '£9.99', ..., '£43.99', '£49.81', '£21.20'],
#       dtype=object)

# %%
import re

# %%
for i in price:
    i = str(i)

# %%
price
# Out:
# array(['£3.42', '£16.99', '£9.99', ..., '£43.99', '£49.81', '£21.20'],
#       dtype=object)

# %%
for i in price:
    i = re.sub("£","",i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\RENANL~1\AppData\Local\Temp/ipykernel_4644/246518752.py in <module>
#       1 for i in price:
# ----> 2     i = re.sub("£","",i)
#
# C:\Python39\lib\re.py in sub(pattern, repl, string, count, flags)
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#     211
#     212 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
price
# Out:
# array(['£3.42', '£16.99', '£9.99', ..., '£43.99', '£49.81', '£21.20'],
#       dtype=object)

# %%
caracter = '£'
for i in price:
    for j in range(len(caracter)):
        i = i.replace(caracter[j],'')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RENANL~1\AppData\Local\Temp/ipykernel_4644/1431011562.py in <module>
#       2 for i in price:
#       3     for j in range(len(caracter)):
# ----> 4         i = i.replace(caracter[j],'')
#
# AttributeError: 'float' object has no attribute 'replace'
